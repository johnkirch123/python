# %%
import requests

# %%
def get_stock_data(stock_symbol, start_date, end_date):
    base_url = 'https://api.tiingo.com/tiingo/daily/' + stock_symbol + '/prices?'
    api_key = '85b4899b4ea2cc6b94a4703cdcb99f78f9a3029b'
    payload = {
        'token': api_key,
        'startDate': start_date,
        'endDate': end_date
    }
    response = requests.get(base_url, params=payload)
    return response

# %%
data_response = get_stock_data('MSFT', '2018-3-25', '2018-4-25')
print(data_response.url)
print(data_response.json())
# Out:
# https://api.tiingo.com/tiingo/daily/MSFT/prices?token=85b4899b4ea2cc6b94a4703cdcb99f78f9a3029b&startDate=2018-3-25&endDate=2018-4-25
# [{'date': '2018-03-26T00:00:00.000Z', 'close': 93.78, 'high': 94.0, 'low': 90.4, 'open': 90.61, 'volume': 55031149, 'adjClose': 91.0031646086, 'adjHigh': 91.2166503861, 'adjLow': 87.7232467543, 'adjOpen': 87.9270286328, 'adjVolume': 55031149, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-03-27T00:00:00.000Z', 'close': 89.47, 'high': 95.139, 'low': 88.51, 'open': 94.94, 'volume': 53704562, 'adjClose': 86.8207841494, 'adjHigh': 92.3219244796, 'adjLow': 85.8892098476, 'adjOpen': 92.1288168899, 'adjVolume': 53704562, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-03-28T00:00:00.000Z', 'close': 89.39, 'high': 91.23, 'low': 88.873, 'open': 89.82, 'volume': 52501146, 'adjClose': 86.7431529576, 'adjHigh': 88.5286703694, 'adjLow': 86.2414613804, 'adjOpen': 87.1604206136, 'adjVolume': 52501146, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-03-29T00:00:00.000Z', 'close': 91.27, 'high': 92.29, 'low': 88.4, 'open': 90.18, 'volume': 45867548, 'adjClose': 88.5674859653, 'adjHigh': 89.557283661, 'adjLow': 85.7824669588, 'adjOpen': 87.5097609768, 'adjVolume': 45867548, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-02T00:00:00.000Z', 'close': 88.52, 'high': 90.88, 'low': 87.51, 'open': 90.47, 'volume': 48515417, 'adjClose': 85.8989137465, 'adjHigh': 88.1890339052, 'adjLow': 84.9188199498, 'adjOpen': 87.7911740471, 'adjVolume': 48515417, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-03T00:00:00.000Z', 'close': 89.71, 'high': 90.05, 'low': 87.89, 'open': 89.575, 'volume': 37213837, 'adjClose': 87.0536777248, 'adjHigh': 87.3836102901, 'adjLow': 85.287568111, 'adjOpen': 86.9226750886, 'adjVolume': 37213837, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-04T00:00:00.000Z', 'close': 92.33, 'high': 92.76, 'low': 87.73, 'open': 87.85, 'volume': 35559956, 'adjClose': 89.5960992569, 'adjHigh': 90.0133669129, 'adjLow': 85.1323057273, 'adjOpen': 85.2487525151, 'adjVolume': 35559956, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-05T00:00:00.000Z', 'close': 92.38, 'high': 93.065, 'low': 91.4, 'open': 92.435, 'volume': 29771881, 'adjClose': 89.6446187518, 'adjHigh': 90.3093358317, 'adjLow': 88.693636652, 'adjOpen': 89.6979901961, 'adjVolume': 29771881, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-06T00:00:00.000Z', 'close': 90.23, 'high': 92.46, 'low': 89.48, 'open': 91.49, 'volume': 38026000, 'adjClose': 87.5582804716, 'adjHigh': 89.7222499436, 'adjLow': 86.8304880484, 'adjOpen': 88.7809717428, 'adjVolume': 38026000, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-09T00:00:00.000Z', 'close': 90.77, 'high': 93.17, 'low': 90.62, 'open': 91.04, 'volume': 31533943, 'adjClose': 88.0822910164, 'adjHigh': 90.411226771, 'adjLow': 87.9367325318, 'adjOpen': 88.3442962888, 'adjVolume': 31533943, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-10T00:00:00.000Z', 'close': 92.88, 'high': 93.28, 'low': 91.64, 'open': 92.39, 'volume': 26939883, 'adjClose': 90.1298137006, 'adjHigh': 90.5179696597, 'adjLow': 88.9265302274, 'adjOpen': 89.6543226507, 'adjVolume': 26939883, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-11T00:00:00.000Z', 'close': 91.86, 'high': 93.29, 'low': 91.48, 'open': 92.01, 'volume': 24872110, 'adjClose': 89.1400160049, 'adjHigh': 90.5276735587, 'adjLow': 88.7712678438, 'adjOpen': 89.2855744896, 'adjVolume': 24872110, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-12T00:00:00.000Z', 'close': 93.58, 'high': 94.16, 'low': 92.43, 'open': 92.43, 'volume': 26758879, 'adjClose': 90.809086629, 'adjHigh': 91.3719127697, 'adjLow': 89.6931382466, 'adjOpen': 89.6931382466, 'adjVolume': 26758879, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-13T00:00:00.000Z', 'close': 93.08, 'high': 94.18, 'low': 92.44, 'open': 94.05, 'volume': 23346063, 'adjClose': 90.3238916802, 'adjHigh': 91.3913205677, 'adjLow': 89.7028421456, 'adjOpen': 91.265169881, 'adjVolume': 23346063, 'divCash': 0.0, 'splitFactor': 1.0}, {'date': '2018-04-16T00:00:00.000Z', 'close': 94.17, 'high': 94.66, 'l ...

# %%
def decode_data(data_response):
    json_response = data_response.json()
    dates = []
    highs = []
    lows = []
    for json_object in json_response:
        date = json_object['date']
        high = json_object['high']
        low = json_object['low']
        dates.append(date)
        highs.append(high)
        lows.append(low)
    return dates, highs, lows

# %%
dates, highs, lows = decode_data(data_response)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dates, highs, label='highs')
plt.plot(dates, lows, label='lows')
plt.title('High and Low Prices of MSFT')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend(loc='upper left')
plt.show()
